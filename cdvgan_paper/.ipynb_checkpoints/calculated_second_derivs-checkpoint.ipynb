# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from utils import calculate_derivative

# %%
with open('data/data.pkl', 'rb') as f:
    data = pickle.load(f)

with open('data/data_deriv.pkl', 'rb') as f:
    data_deriv = pickle.load(f)

# %%
data_deriv_fn = calculate_derivative(np.arange(len(data[0]), dtype=np.float64), data)
data_deriv2_fn = calculate_derivative(np.arange(len(data_deriv_fn[0]), dtype=np.float64), data_deriv_fn)

# %%
plt.figure(figsize=(9,5))
for i in range(9):
  plt.subplot(3, 3, i+1)
  plt.plot(data[i])
  
plt.show()

plt.figure(figsize=(9,5))
for i in range(9):
  plt.subplot(3, 3, i+1)
  plt.plot(data_deriv_fn[i])
  
plt.show()

plt.figure(figsize=(9,5))
for i in range(9):
  plt.subplot(3, 3, i+1)
  plt.plot(data_deriv2_fn[i])
  
plt.show()

# %%
with open('data/data_deriv2.pkl', 'wb') as f:
    pickle.dump(data_deriv2_fn, f)
